# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/pic"
# Out:
# /content/drive/MyDrive/pic

# %%
import os

# %%
print(len(os.listdir('/content/drive/MyDrive/pic/train')))
# Out:
# 5027

# %%
print(len(os.listdir('/content/drive/MyDrive/pic/test1')))
# Out:
# 12500

# %%
file_list = ['/content/drive/MyDrive/pic/train/cat', '/content/drive/MyDrive/pic/train/dog']
for path in file_list:
    os.mkdir(path)

# %%
import shutil

# %%
fnames = os.listdir('/content/drive/MyDrive/pic/train')
cat_fname = fnames[2:2516]
for fname in cat_fname:
  src = os.path.join('/content/drive/MyDrive/pic/train', fname)
  dst = os.path.join(os.path.join('/content/drive/MyDrive/pic/train/cat'), fname)
  shutil.copyfile(src, dst)

# %%
print(len(os.listdir('/content/drive/MyDrive/pic/train/cat')))
# Out:
# 2514
